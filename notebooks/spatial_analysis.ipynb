# %%
# !pip install -r ../requirements.txt
# Out:
# Requirement already satisfied: pandas in c:\users\prarthana pn\onedrive\desktop\geospatiial_modelling\geospatial-modelling-pfas\venv\lib\site-packages (from -r ../requirements.txt (line 1)) (3.0.1)
# Requirement already satisfied: numpy in c:\users\prarthana pn\onedrive\desktop\geospatiial_modelling\geospatial-modelling-pfas\venv\lib\site-packages (from -r ../requirements.txt (line 2)) (2.4.3)
# Requirement already satisfied: geopandas in c:\users\prarthana pn\onedrive\desktop\geospatiial_modelling\geospatial-modelling-pfas\venv\lib\site-packages (from -r ../requirements.txt (line 3)) (1.1.3)
# Requirement already satisfied: shapely in c:\users\prarthana pn\onedrive\desktop\geospatiial_modelling\geospatial-modelling-pfas\venv\lib\site-packages (from -r ../requirements.txt (line 4)) (2.1.2)
# Requirement already satisfied: pyproj in c:\users\prarthana pn\onedrive\desktop\geospatiial_modelling\geospatial-modelling-pfas\venv\lib\site-packages (from -r ../requirements.txt (line 5)) (3.7.2)
# Requirement already satisfied: pyogrio in c:\users\prarthana pn\onedrive\desktop\geospatiial_modelling\geospatial-modelling-pfas\venv\lib\site-packages (from -r ../requirements.txt (line 6)) (0.12.1)
# Requirement already satisfied: pyarrow in c:\users\prarthana pn\onedrive\desktop\geospatiial_modelling\geospatial-modelling-pfas\venv\lib\site-packages (from -r ../requirements.txt (line 7)) (23.0.1)
# Requirement already satisfied: scipy in c:\users\prarthana pn\onedrive\desktop\geospatiial_modelling\geospatial-modelling-pfas\venv\lib\site-packages (from -r ../requirements.txt (line 8)) (1.17.1)
# Requirement already satisfied: matplotlib in c:\users\prarthana pn\onedrive\desktop\geospatiial_modelling\geospatial-modelling-pfas\venv\lib\site-packages (from -r ../requirements.txt (line 9)) (3.10.8)
# Requirement already satisfied: scikit-learn in c:\users\prarthana pn\onedrive\desktop\geospatiial_modelling\geospatial-modelling-pfas\venv\lib\site-packages (from -r ../requirements.txt (line 10)) (1.8.0)
# Requirement already satisfied: xgboost in c:\users\prarthana pn\onedrive\desktop\geospatiial_modelling\geospatial-modelling-pfas\venv\lib\site-packages (from -r ../requirements.txt (line 11)) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\prarthana pn\onedrive\desktop\geospatiial_modelling\geospatial-modelling-pfas\venv\lib\site-packages (from pandas->-r ../requirements.txt (line 1)) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\prarthana pn\onedrive\desktop\geospatiial_modelling\geospatial-modelling-pfas\venv\lib\site-packages (from pandas->-r ../requirements.txt (line 1)) (2025.3)
# Requirement already satisfied: packaging in c:\users\prarthana pn\onedrive\desktop\geospatiial_modelling\geospatial-modelling-pfas\venv\lib\site-packages (from geopandas->-r ../requirements.txt (line 3)) (26.0)
# Requirement already satisfied: certifi in c:\users\prarthana pn\onedrive\desktop\geospatiial_modelling\geospatial-modelling-pfas\venv\lib\site-packages (from pyproj->-r ../requirements.txt (line 5)) (2026.2.25)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\prarthana pn\onedrive\desktop\geospatiial_modelling\geospatial-modelling-pfas\venv\lib\site-packages (from matplotlib->-r ../requirements.txt (line 9)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\prarthana pn\onedrive\desktop\geospatiial_modelling\geospatial-modelling-pfas\venv\lib\site-packages (from matplotlib->-r ../requirements.txt (line 9)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\prarthana pn\onedrive\desktop\geospatiial_modelling\geospatial-modelling-pfas\venv\lib\site-packages (from matplotlib->-r ../requirements.txt (line 9)) (4.62.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\prarthana pn\onedrive\desktop\geospatiial_modelling\geospatial-modelling-pfas\venv\lib\site-packages (from matplotlib->-r ../requirements.txt (line 9)) (1.5.0)
# Requirement already satisfied: pillow>=8 in c:\users\prarthana pn\onedrive\desktop\geospatiial_modelling\geospatial-modelling-pfas\venv\lib\site-packages (from matplotlib->-r ../requirements.txt (line 9)) (12.1.1)
# Requirement already satisfied: pyparsing>=3 in c:\users\prarthana pn\onedrive\desktop\geospatiial_modelling\geospatial-modelling-pfas\venv\lib\site-packages (from matplotlib->-r ../requirements.txt (line 9)) (3.3.2)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\prarthana pn\onedrive\desktop\geospatiial_modelling\geospatial-modelling-pfas\venv\lib\site-packages (from scikit-learn->-r ../requirements.txt (line 10)) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\prarthana pn\onedrive\desktop\geospatiial_modelling\geospatial-modelling-pfas\venv\lib\site-packages (from scikit-learn->-r ../requirements.txt (line 10)) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\prarthana pn\onedrive\desktop\geospatiial_modelling\geospatial-modelling-pfas\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->-r ../requirements.txt (line 1)) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import geopandas as gpd
import matplotlib.pyplot as plt

gdf = gpd.read_parquet("../data/processed/PFOS.parquet")

print(gdf.shape)
gdf.head()
# Out:
# (22846, 4)
#          lat        lon      value                    geometry
# 0 -21.364356  55.733356  11.700000  POINT (55.73336 -21.36436)
# 1 -21.354096  55.623506   0.500000   POINT (55.62351 -21.3541)
# 2 -21.330124  55.487014   0.783333  POINT (55.48701 -21.33012)
# 3 -21.325085  55.474879   2.342857  POINT (55.47488 -21.32508)
# 4 -21.310517  55.468648   0.800000  POINT (55.46865 -21.31052)

# %%
gdf.plot(markersize=1)
plt.title("PFOS Contamination Locations")
plt.show()

# %%
from sklearn.cluster import DBSCAN

coords = gdf[["lat","lon"]]

db = DBSCAN(eps=0.5, min_samples=10)
gdf["cluster"] = db.fit_predict(coords)

print(gdf["cluster"].value_counts())
# Out:
# cluster
#  10    20754
# -1       977
#  29      113
#  30       99
#  22       84
#  9        79
#  0        51
#  6        50
#  32       49
#  2        48
#  24       39
#  26       39
#  7        37
#  14       37
#  8        36
#  20       31
#  16       29
#  4        23
#  33       22
#  5        21
#  18       21
#  19       20
#  15       17
#  17       17
#  25       16
#  27       15
#  3        14
#  13       13
#  35       13
#  11       12
#  1        11
#  21       11
#  23       11
#  31       11
#  12       10
#  34       10
#  28        6
# Name: count, dtype: int64

# %%
gdf.plot(column="cluster", legend=True, markersize=1)
plt.title("PFOS Contamination Hotspots")
plt.show()

# %%
import pandas as pd

df = pd.read_parquet("../data/raw/processed_PFAs.parquet")

df.shape
# Out:
# (3815352, 17)

# %%
# 1. Standardize column names (lowercase and replace spaces with underscores)
df.columns = df.columns.str.lower().str.replace(" ", "_")

# 2. Drop rows with missing spatial coordinates and missing values
df = df.dropna(subset=["lat", "lon"])
df = df.dropna(subset=["value"])

# 3. Drop unnecessary columns to go from 17 columns down to 15
df = df.drop(columns=["sector", "city"])

# Check the new shape
print(df.shape)
# Out:
# (612930, 15)

# %%
from sklearn.cluster import DBSCAN
import numpy as np

print("Running optimized DBSCAN...")

# 1. Filter for significant contamination (e.g., PFOS > 10.0 ng/L is high for many standards)
# This ensures we are clustering *toxic* sites, not just *sampled* sites.
# We create a copy to avoid SettingWithCopyWarnings
high_contamination = gdf[gdf["value"] > 10].copy()

if len(high_contamination) < 5:
    print("Not enough high-contamination points to form stable clusters.")
else:
    # 2. Extract coordinates and convert directly to Radians for Haversine
    coords = high_contamination[["lat", "lon"]]
    coords_radians = np.radians(coords)
    
    # 3. Set DBSCAN Parameters for Earth Geometry
    # We want points within a 5 km radius to cluster together
    epsilon_km = 5.0 
    earth_radius_km = 6371.0088
    epsilon_radians = epsilon_km / earth_radius_km
    
    # 4. Run DBSCAN with Haversine metric and Ball Tree algorithm (for spherical spaces)
    db = DBSCAN(eps=epsilon_radians, min_samples=5, metric='haversine', algorithm='ball_tree')
    high_contamination["cluster"] = db.fit_predict(coords_radians)
    
    print(f"Total high-contamination sites: {len(high_contamination)}")
    print("Hotspot Cluster Breakdown:")
    print(high_contamination["cluster"].value_counts())
    
    # 5. Add the cluster labels back to our main geodataframe
    # Default everything to -999 (not clustered/low concern)
    gdf["cluster"] = -999
    
    # Use the index of high_contamination to map the clusters back to the original rows
    gdf.loc[high_contamination.index, "cluster"] = high_contamination["cluster"]
# Out:
# Running optimized DBSCAN...
# Total high-contamination sites: 11268
# Hotspot Cluster Breakdown:
# cluster
#  32     3056
# -1      2974
#  100    1658
#  35      839
#  8       533
#         ...
#  2         4
#  17        4
#  59        4
#  74        4
#  94        4
# Name: count, Length: 161, dtype: int64

# %%
from sklearn.cluster import DBSCAN
import geopandas as gpd
import numpy as np

# 1. Load the data (so 'gdf' is defined)
gdf = gpd.read_parquet("../data/processed/PFOS.parquet")

print("Running optimized DBSCAN...")

# 2. Filter for significant contamination (e.g., PFOS > 10.0 ng/L is high for many standards)
# This ensures we are clustering *toxic* sites, not just *sampled* sites.
high_contamination = gdf[gdf["value"] > 10].copy()

if len(high_contamination) < 5:
    print("Not enough high-contamination points to form stable clusters.")
else:
    # 3. Extract coordinates and convert directly to Radians for Haversine
    coords = high_contamination[["lat", "lon"]]
    coords_radians = np.radians(coords)
    
    # 4. Set DBSCAN Parameters for Earth Geometry
    # We want points within a 5 km radius to cluster together
    epsilon_km = 5.0 
    earth_radius_km = 6371.0088
    epsilon_radians = epsilon_km / earth_radius_km
    
    # 5. Run DBSCAN with Haversine metric and Ball Tree algorithm (for spherical spaces)
    db = DBSCAN(eps=epsilon_radians, min_samples=5, metric='haversine', algorithm='ball_tree')
    high_contamination["cluster"] = db.fit_predict(coords_radians)
    
    print(f"Total high-contamination sites: {len(high_contamination)}")
    print("Hotspot Cluster Breakdown:")
    print(high_contamination["cluster"].value_counts())
    
    # 6. Add the cluster labels back to our main geodataframe
    # Default everything to -999 (not clustered/low concern)
    gdf["cluster"] = -999
    
    # Use the index of high_contamination to map the clusters back to the original rows
    gdf.loc[high_contamination.index, "cluster"] = high_contamination["cluster"]
# Out:
# Running optimized DBSCAN...
# Total high-contamination sites: 11268
# Hotspot Cluster Breakdown:
# cluster
#  32     3056
# -1      2974
#  100    1658
#  35      839
#  8       533
#         ...
#  2         4
#  17        4
#  59        4
#  74        4
#  94        4
# Name: count, Length: 161, dtype: int64

# %%
import matplotlib.pyplot as plt

# 1. Create a large, readable figure
fig, ax = plt.subplots(figsize=(12, 8))

# 2. Separate the data into "Hotspots" and "Background"
# In DBSCAN, -1 means "Noise" (isolated points), and we set -999 as low contamination.
# So valid clusters are any numbers >= 0.
hotspots = gdf[gdf["cluster"] >= 0].copy()
background = gdf[gdf["cluster"] < 0].copy()

# 3. Plot the background faintly
background.plot(ax=ax, markersize=1, color="lightgray", alpha=0.5)

# 4. Plot the actual hotspots
if not hotspots.empty:
    hotspots.plot(
        ax=ax, 
        column="cluster", 
        categorical=True,  
        cmap="Set1",
        markersize=25,
        legend=True,
        legend_kwds={"title": "Hotspot Cluster ID", "loc": "lower right"}
    )

# 5. Add labels and formatting
plt.title("Critical PFOS Contamination Hotspots (PFOS > 10ng/L, 5km Radius)", fontsize=14)
plt.xlabel("Longitude")
plt.ylabel("Latitude")
plt.grid(True, linestyle=":", alpha=0.6)

plt.tight_layout()
plt.show()
# Out:
# C:\Users\PRARTHANA PN\AppData\Local\Temp\ipykernel_28384\3594922989.py:33: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
